# %%
pip install cellxgene[prepare]
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fb88cba75e0>: Failed to establish a new connection: [Errno 111] Connection refused'))': /simple/cellxgene/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fb88cba7ac0>: Failed to establish a new connection: [Errno 111] Connection refused'))': /simple/cellxgene/
# ...

# %%
pip install cellxgene
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f59e0572670>: Failed to establish a new connection: [Errno 111] Connection refused'))': /simple/cellxgene/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f59e0572b50>: Failed to establish a new connection: [Errno 111] Connection refused'))': /simple/cellxgene/
# ...
