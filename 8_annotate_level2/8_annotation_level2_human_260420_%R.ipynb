# %% [markdown]
# ## ECs

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/Endothelial_cell/level2_ec_pre_annot.rds")
# level1_marker <- list(
#     "Arterial endothelial cell" = c('GJ4', 'GJ5', "GATA2", "MECOM", "GJA4", "GJA5"),
#     "Lymphatic endothelial cell" = c("LYVE1", "CCL21")
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/Endothelial_cell/level2_ec_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## Macrophage

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/Macrophage/level2_macros_pre_annot.rds")
# level1_marker <- list(
#     "Inflammatory macrophage" = c('S100A8', 'IL1B', 'S100A9','IRF7', 'IFITM3', 'ISG15', 'IFIT2'),
#     "Foamy macrophage" = c('TREM2', 'MARCO', 'FABP4','FABP5', 'CD36'),
#     "Homeostatic/Resident macrophage" = c('LYVE1', 'MRC1', 'F13A1', 'SEPP1', 'IGF1', 'GAS6', 'MERTK', 'STAB1', 'C1QA', 'C1QB', 'C1QC', 'FOLR2'),
#     "Proliferative macrophage" = c('MKI67', 'TOP2A', 'PCNA', 'BIRC5', 'MCM2','MCM4','MCM5', 'TK1'),
#     "Matrix-remodeling/SMC-like macrophage" = c('AEBP1', 'COL1A1', 'COL1A2', 'THBS2', 'MMP3', 'S100A16', 'TNC', 'PDGFRB')
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/Macrophage/level2_macros_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## DCs

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/Dendritic_cell/level2_dc_pre_annot.rds")
# level1_marker <- list(
#     "cDC1" = c("CLEC9A", "IRF8", "SNX3"),
#     "cDC2" = c("CD1C", "CLEC10A", "FCER1A"),
#     "Plasmacytoid dendritic cell" = c("IRF7", "TLR7", "TLR9", "NRP1", "CLEC4C", "SCAMP5", "GZMB", "TCF4")
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/Dendritic_cell/level2_dc_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## T cells

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/T_cell/level2_tc_pre_annot.rds")
# level1_marker <- list(
#     "CD8 T cell" = c('CCL4L2', 'CRTAM', 'GZMK', 'CCL4', 'CD8A', 'GZMH'),
#     "CD4 T cell" = c('IL7R', 'ANXA1', 'FTH1', 'CD4', 'BATF', 'TNFRSF4', 'TNFRSF18')
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/T_cell/level2_tc_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## B cells

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/B_cell/level2_bc_pre_annot.rds")
# level1_marker <- list(
#     "B cell" = c('CD79A', 'CD79B', 'MS4A1', 'CD22', 'FCER2'),
#     "Plasma cell" = c('IGKC', 'IGHM', 'IGHA1', 'IGLC2', 'IGLC3', 'JCHAIN'),
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/B_cell/level2_bc_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## Monocyte

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/Monocyte/level2_mono_pre_annot.rds")
# level1_marker <- list(
#     "Classical monocyte" = c('CD14', 'FCN1', 'LST1', 'VCAN', 'CCR2', 'SELL', 'CTSS'),
#     "Intermediate monocyte" = c('MS4A7', 'HLA-DPA1', 'HLA-DPB1', 'ITGAX', 'IRF7', 'STAT1'),
#     "Non-classical monocyte" = c('FCGR3A', 'CX3CR1', 'NR4A1', 'ITGAL', 'PDE4B', 'LILRB1', 'HSPA1A')
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/Monocyte/level2_mono_pre_annot.csv",row.names = FALSE, )

# %% [markdown]
# ## SMC

# %%
# %%R
# library(Seurat)
# library(openxlsx)
# library(Matrix)
# library(stringr)
# library(dplyr)
# adata <- readRDS("./output_260420/SMC/level2_smc_pre_annot.rds")
# level1_marker <- list(
#     "Smooth muscle cell" = c('MYH11','MYL9','TPM2','CALD1','TAGLN','APOE','APOC1','AGT','NOTCH3','PDGFRB','MFAP4'),
#     "Fibromyocyte" = c('FN1','LUM','TNFRSF11B','ACTA2','TCF21')
# )
# str(level1_marker)
#
# sc <- AddModuleScore(object = adata,features = level1_marker,ctrl = 100,name = "ModuleScore_",assay = "RNA",slot = "counts")
# module_score_cols <- grep("ModuleScore_", colnames(sc@meta.data), value = TRUE)
# #按聚类分组，计算每个模块的平均得分
# cluster_module_score_table <- sc@meta.data %>%group_by(leiden) %>%summarise(across(all_of(module_score_cols), mean), .groups = "drop") %>%
#   rename(Cluster = leiden)
# cluster_top_module <- apply(cluster_module_score_table[, -1], 1, function(x) colnames(cluster_module_score_table[, -1])[which.max(x)])
# cluster_top_celltype <- gsub("ModuleScore_", "", cluster_top_module)
# cluster_module_score_table$Top_Matched_CellType <- cluster_top_celltype
# write.csv(cluster_module_score_table,file = "./output_260420/SMC/level2_smc_pre_annot.csv",row.names = FALSE, )
