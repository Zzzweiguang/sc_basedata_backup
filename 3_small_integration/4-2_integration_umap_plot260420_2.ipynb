# %%
import warnings
# 忽略所有 DeprecationWarning
warnings.filterwarnings("ignore", category=DeprecationWarning, module="scib|scgen|typing_extensions")

import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import anndata
import os
from scipy.sparse import issparse
import scvi
import scib
from scarches.models.scpoli import scPoli
import scarches as sca
from harmony import harmonize
import pyliger
from scarches.dataset.trvae.data_handling import remove_sparsity
import dask.dataframe as dd
import time
os.getcwd()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (
# WARNING:root:In order to use the mouse gastrulation seqFISH datsets, please install squidpy (see https://github.com/scverse/squidpy).
# WARNING:root:In order to use sagenet models, please install pytorch geometric (see https://pytorch-geometric.readthedocs.io) and
#  captum (see https://github.com/pytorch/captum).
# WARNING:root:mvTCR is not installed. To use mvTCR models, please install it first using "pip install mvtcr"
# ...

# %% [markdown]
# ## UMAP-dim=5 eta=2 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim5-eta2.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### harmony

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['Harmony']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="harmony_cell_type1",save='_cell_type-harmony.png')
sc.pl.umap(adata,color='sample',title="harmony_sample",save='_sample-harmony.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type-harmony.png
# WARNING: saving figure to file figures/umap_2/umap_sample-harmony.png

# %% [markdown]
# ### scANVI

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scANVI']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scANVI_cell_type1",save='_cell_type-scANVI.png')
sc.pl.umap(adata,color='sample',title="scANVI_sample",save='_sample-scANVI.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type-scANVI.png
# WARNING: saving figure to file figures/umap_2/umap_sample-scANVI.png

# %% [markdown]
# ### scVI

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scVI']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scVI_cell_type1",save='_cell_type-scVI.png')
sc.pl.umap(adata,color='sample',title="scVI_sample",save='_sample-scVI.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type-scVI.png
# WARNING: saving figure to file figures/umap_2/umap_sample-scVI.png

# %% [markdown]
# ### LIGER

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['LIGER']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="LIGER_cell_type1",save='_cell_type-LIGER.png')
sc.pl.umap(adata,color='sample',title="LIGER_sample",save='_sample-LIGER.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type-LIGER.png
# WARNING: saving figure to file figures/umap_2/umap_sample-LIGER.png

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim5_eta2-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim5_eta2-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim5_eta2-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim5_eta2-scPoli.png

# %% [markdown]
# ### PCA

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['PCA']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="PCA_cell_type1",save='_cell_type-PCA.png')
sc.pl.umap(adata,color='sample',title="PCA_sample",save='_sample-PCA.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type-PCA.png
# WARNING: saving figure to file figures/umap_2/umap_sample-PCA.png

# %% [markdown]
# ## UMAP-dim=5 eta=5 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim5-eta5.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim5_eta5-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim5_eta5-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim5_eta5-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim5_eta5-scPoli.png

# %% [markdown]
# ## UMAP-dim=5 eta=10 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim5-eta10.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim5_eta10-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim5_eta10-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim5_eta10-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim5_eta10-scPoli.png

# %% [markdown]
# ## UMAP-dim=10 eta=2 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim10-eta2.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim10_eta2-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim10_eta2-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim10_eta2-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim10_eta2-scPoli.png

# %% [markdown]
# ## UMAP-dim=10 eta=5 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim10-eta5.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim10_eta5-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim10_eta5-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim10_eta5-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim10_eta5-scPoli.png

# %% [markdown]
# ## UMAP-dim=10 eta=10 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim10-eta10.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim10_eta10-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim10_eta10-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim10_eta10-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim10_eta10-scPoli.png

# %% [markdown]
# ## UMAP-dim=15 eta=2 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim15-eta2.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim15_eta2-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim15_eta2-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim15_eta2-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim15_eta2-scPoli.png

# %% [markdown]
# ## UMAP-dim=15 eta=5 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim15-eta5.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim15_eta5-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim15_eta5-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim15_eta5-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim15_eta5-scPoli.png

# %% [markdown]
# ## UMAP-dim=15 eta=10 mse

# %%
adata = sc.read_h5ad('./3_3_train_py_no_IAISR_0507/output_260420/small-concat-ensembl-aggr-sparse-method-noIAISR-mse-dim15-eta10.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 475147 × 2000
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'leiden', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'conditions_combined'
#     var: 'original_gene_names', 'highly_variable'
#     uns: 'log1p', 'neighbors', 'pca'
#     obsm: 'Harmony', 'LIGER', 'PCA', 'scANVI', 'scPoli', 'scVI'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### scPoli

# %%
outdir = "./figures/umap_2"
os.makedirs(outdir, exist_ok=True)
sc.settings.figdir = outdir

adata.obsm['X_pca'] = adata.obsm['scPoli']
sc.pp.neighbors(adata)
sc.tl.umap(adata)

sc.pl.umap(adata,color='cell_type_level1',title="scPoli_cell_type1",save='_cell_type_dim15_eta10-scPoli.png')
sc.pl.umap(adata,color='sample',title="scPoli_sample",save='_sample_dim15_eta10-scPoli.png')
# Out:
# WARNING: saving figure to file figures/umap_2/umap_cell_type_dim15_eta10-scPoli.png
# WARNING: saving figure to file figures/umap_2/umap_sample_dim15_eta10-scPoli.png
