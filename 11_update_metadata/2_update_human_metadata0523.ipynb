# %%
import scanpy as sc

# %%
adata_final_umap = sc.read_h5ad("../9_annotate_level3/0521_no_Basophil/output_allhuman/scPoli_concat_level3_marker_all.h5ad")
adata_final_umap
# Out:
# AnnData object with n_obs × n_vars = 1004247 × 28868
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'atlas_key', 'species', 'barcode_for_match', 'match_id', 'leiden', 'cell_type_pred', 'cell_type_uncert', 'query', 'cell_type_pred_ref', 'cell_type_level1_human', 'cell_type_level1_corrected', 'cell_type_level2', 'cell_type_level3'
#     var: 'original_gene_names', 'ensembl_id'
#     uns: 'neighbors', 'umap'
#     obsm: 'X_scPoli', 'X_umap'
#     layers: 'counts', 'raw_decontXcounts', 'rounded_corrected_counts', 'uncorrected_counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_final_umap.obs['tissue'].value_counts()
# Out:
# tissue
# Aorta              237585
# Carotid Artery     216368
# Coronary artery     59774
# Coronary Artery     43510
# Femoral Artery      35421
# Name: count, dtype: int64

# %%
adata_final_umap.obs['symptoms'].value_counts()
# Out:
# symptoms
# not stated         411589
# Atherosclerosis    295299
# AAA                106914
# Healthy             99283
# ATAA                38528
# AD                  32478
# MF                  14828
# TAA                  5328
# Name: count, dtype: int64

# %% [markdown]
# #### tissue

# %%
##改组织部位
####GSE226492
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].astype(str)
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_1", "GSE226492_2", "GSE226492_3"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_4", "GSE226492_5", "GSE226492_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_7", "GSE226492_8", "GSE226492_9","GSE226492_10"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE226492"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Aorta              47306
# Ascending Aorta    30776
# Abdominal Aorta    12453
# Name: count, dtype: int64

# %%
####GSE224587
sample_mask = adata_final_umap.obs["sample"].isin(["GSE224587_1", "GSE224587_2", "GSE224587_3", "GSE224587_4", "GSE224587_5", "GSE224587_6", "GSE224587_7", "GSE224587_8"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    81796
# Name: count, dtype: int64

# %%
####GSE237230
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_1", "GSE237230_2", "GSE237230_3", "GSE237230_4", "GSE237230_5", "GSE237230_6", "GSE237230_7", "GSE237230_8"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE237230"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    4219
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1", "GSE166676_2", "GSE166676_3", "GSE166676_4", "GSE166676_5", "GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    9019
# Name: count, dtype: int64

# %%
####GSE143921
sample_mask = adata_final_umap.obs["sample"].isin(["GSE143921_1", "GSE143921_2", "GSE143921_3", "GSE143921_4", "GSE143921_5", "GSE143921_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE143921"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Ascending Aorta    5328
# Name: count, dtype: int64

# %%
####GSE155468
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_1", "GSE155468_2", "GSE155468_3", "GSE155468_4", "GSE155468_5", "GSE155468_6",
                                                   "GSE155468_7", "GSE155468_8", "GSE155468_9", "GSE155468_10", "GSE155468_11"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE155468"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Ascending Aorta    46688
# Name: count, dtype: int64

# %%
####GSE155512
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155512_1", "GSE155512_2", "GSE155512_3"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE155512"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    8830
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2", "GSE159677_3", "GSE159677_4", "GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    45269
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1", "GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3", "GSE179159_4", "GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    15684
# Carotid Artery      4224
# Name: count, dtype: int64

# %%
####GSE210152
sample_mask = adata_final_umap.obs["sample"].isin(["GSE210152_1", "GSE210152_2", "GSE210152_3", "GSE210152_4", "GSE210152_5", "GSE210152_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE210152"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    30243
# Name: count, dtype: int64

# %%
####GSE224273
sample_mask = adata_final_umap.obs["sample"].isin(["GSE224273_1", "GSE224273_2", "GSE224273_3", "GSE224273_4", "GSE224273_5", "GSE224273_6", "GSE224273_7"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE224273"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    9828
# Name: count, dtype: int64

# %%
####GSE247238
mask = adata_final_umap.obs["dataset"] == "GSE247238"
adata_final_umap.obs.loc[mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE247238"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    4684
# Name: count, dtype: int64

# %%
####GSE234077
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_2", "GSE234077_7", "GSE234077_9"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_1", "GSE234077_3", "GSE234077_4", "GSE234077_5", "GSE234077_6", "GSE234077_8", "GSE234077_10"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Femoral Artery"
mask = adata_final_umap.obs["dataset"] == "GSE234077"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Femoral Artery    35421
# Carotid Artery    25763
# Name: count, dtype: int64

# %%
####GSE253904
mask = adata_final_umap.obs["dataset"] == "GSE253904"
adata_final_umap.obs.loc[mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE253904"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    76038
# Name: count, dtype: int64

# %%
####GSE131778
mask = adata_final_umap.obs["dataset"] == "GSE131778"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE131778"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    11489
# Name: count, dtype: int64

# %%
####GSE184073
mask = adata_final_umap.obs["dataset"] == "GSE184073"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE184073"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    1685
# Name: count, dtype: int64

# %%
####GSE196943
mask = adata_final_umap.obs["dataset"] == "GSE196943"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE196943"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    26141
# Name: count, dtype: int64

# %%
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].replace('nan', 'Unknown')
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].replace('Coronary artery', 'Coronary Artery')
adata_final_umap.obs['tissue'].value_counts()
# Out:
# tissue
# Unknown            411589
# Carotid Artery     204879
# Coronary Artery    114773
# Abdominal Aorta    107487
# Ascending Aorta     82792
# Aorta               47306
# Femoral Artery      35421
# Name: count, dtype: int64

# %%
datasets_to_change = [
    '2_ZDZJ',
    'AAA-MAX',
    'AAA-P',
    'AAA-PRO'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Abdominal Aorta"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Abdominal Aorta    40408
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AS-CFA',
    'AS-FA',
    'CFA-BWD',
    'CFA-PLA',
    'ISR-7-1',
    'POP-ISR2-B',
    'SFA-8',
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Femoral Artery"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Femoral Artery    64521
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AS-POP'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Popliteal Artery"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Popliteal Artery    7232
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AIOD-3LIB',
    'IA-1-3LIB',
    'IAISR'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Iliac Artery"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Iliac Artery    22999
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'CBT',
    'ISR-7-2',
    'ISR-8'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Carotid Artery"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Carotid Artery    22074
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'TAA-A1-5-3LIB',
    'TAA-B1-5-3LIB',
    'TAD1-Z3-3LIB',
    'TAD2-Z1-3LIB',
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "tissue"] = "Thoracic Aorta"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["tissue"].value_counts()
# Out:
# tissue
# Thoracic Aorta    25647
# Name: count, dtype: int64

# %%
adata_final_umap.obs['tissue'].value_counts()
# Out:
# tissue
# Unknown             228708
# Carotid Artery      226953
# Abdominal Aorta     147895
# Coronary Artery     114773
# Femoral Artery       99942
# Ascending Aorta      82792
# Aorta                47306
# Thoracic Aorta       25647
# Iliac Artery         22999
# Popliteal Artery      7232
# Name: count, dtype: int64

# %%
# adata_final_umap.write_h5ad("../9_annotate_level3/0521_no_Basophil/output_allhuman/scPoli_concat_level3_marker_all_metadata.h5ad")

# %% [markdown]
# #### symptoms

# %%
# adata_final_umap = sc.read_h5ad("../9_annotate_level3/0514_rename_level3/output_allhuman/work_0514/scPoli_concat_level3_marker_all_metadata.h5ad")

# %%
####GSE224587
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_final_umap.obs.loc[mask, "symptoms"] = "Atherosclerosis"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# Atherosclerosis    81796
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5"])
adata_final_umap.obs.loc[sample_mask, "symptoms"] = "Healthy"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# AAA        7085
# Healthy    1934
# Name: count, dtype: int64

# %%
####GSE143921
sample_mask = adata_final_umap.obs["sample"].isin(["GSE143921_1", "GSE143921_2", "GSE143921_3"])
adata_final_umap.obs.loc[sample_mask, "symptoms"] = "Healthy"
mask = adata_final_umap.obs["dataset"] == "GSE143921"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# TAA        2951
# Healthy    2377
# Name: count, dtype: int64

# %%
datasets_to_change = [
    '1_JD',
    '2_ZDZJ',
    'AAA',
    'AAA-1-3LIB',
    'AAA_2_3LIB',
    'AAA_3_3LIB',
    'AAA_4_3LIB',
    'AAA_8',
    'AAA_9',
    'AAA_D',
    'AAA_MAX',
    'AAA_P',
    'AAA_PRO',
    'RRAA'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "AAA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# AAA    130678
# Name: count, dtype: int64

# %%
adata_final_umap.obs['symptoms'] = adata_final_umap.obs['symptoms'].astype(str)
datasets_to_change = [
    'AIOD_3LIB',
    'IA_1_3LIB'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "IAA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# IAA    22999
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'CBT'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "CBT"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# CBT    8266
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'CFA_BWD',
    'CFA_PLA',
    'AS_CFA',
    'AS_FA',
    'AS_POP',
    'MXT_matrix',
    'SFA_8'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "Atherosclerosis"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# Atherosclerosis    51227
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'IAISR',
    'ISR_7_1',
    'ISR_7_2',
    'ISR_8',
    'ISR_9',
    'LCH_matrix',
    'LHJ20230414_matrix',
    'LW_matrix',
    'POP_ISR_A',
    'POP_ISR2_B',
    'S221031_matrix',
    'ZNB_matrix'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "Atherosclerosis,ISR"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# Atherosclerosis,ISR    78175
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'TAA_A1_3_3LIB',
    'TAA_A1_5_3LIB',
    'TAA_B1_5_3LIB',
    'TAA_Z1',
    'TAA_Z3',
    'TAD_AD1_2_3LIB',
    'TAD1_Z3_3LIB',
    'TAD2_Z1_3LIB',
    'TAD2_Z2_3LIB',
    'TAD2_Z3_3LIB'
]
mask = adata_final_umap.obs["sample"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "symptoms"] = "TAA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# TAA    80606
# Name: count, dtype: int64

# %%
adata_final_umap.obs['symptoms'].value_counts()
# Out:
# symptoms
# Atherosclerosis        428322
# AAA                    154435
# Healthy                103021
# TAA                     83557
# Atherosclerosis,ISR     78175
# not stated              39638
# ATAA                    38528
# AD                      32478
# IAA                     22999
# MF                      14828
# CBT                      8266
# Name: count, dtype: int64

# %%
adata_final_umap.obs['symptoms'] = adata_final_umap.obs['symptoms'].replace({
    'not stated': 'Unknown'
})

# %%
adata_final_umap.obs['symptoms'].value_counts()
# Out:
# symptoms
# Atherosclerosis        428322
# AAA                    154435
# Healthy                103021
# TAA                     83557
# Atherosclerosis,ISR     78175
# Unknown                 39638
# ATAA                    38528
# AD                      32478
# IAA                     22999
# MF                      14828
# CBT                      8266
# Name: count, dtype: int64

# %%
# adata_final_umap.write_h5ad("../9_annotate_level3/0514_rename_level3/output_allhuman/work_0514/scPoli_concat_level3_marker_all_metadata.h5ad")

# %% [markdown]
# #### age

# %%
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].astype(str)
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].replace('nan', float('nan'))
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].fillna('Unknown')

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown                752544
# 69-80 years             30243
# 75 years                21692
# 65 years                20092
# 87 years                19024
# 62 years                15728
# 67 years                13022
# 82 years                13016
# 64 years                11159
# 76 years                 9418
# 77 years                 8742
# 67.2 years(average)      8446
# 78 years                 8312
# 66 years                 7814
# 59 years                 6975
# 69 years                 6894
# 70 years                 5927
# 71 years                 4241
# 80 years                 4195
# 58 years                 3910
# 81 years                 3873
# 56 years                 3847
# 74 years                 3842
# 46 years                 3713
# 63 years                 3063
# 54 years                 2891
# 47 years                 2696
# 83 years                 2614
# 89 years                 2586
# 79 years                 1964
# 61 years                 1191
# ...

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1", "GSE166676_2", "GSE166676_3", "GSE166676_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "52-83 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5", "GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "age"] = "57-62 years"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 52-83 years    7085
# 57-62 years    1934
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2"])
adata_final_umap.obs.loc[sample_mask, "age"] = "82 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_3", "GSE159677_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "87 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "age"] = "65 years"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 87 years    19024
# 65 years    13229
# 82 years    13016
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1"])
adata_final_umap.obs.loc[sample_mask, "age"] = "74 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "age"] = "77 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3"])
adata_final_umap.obs.loc[sample_mask, "age"] = "70 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "59 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "age"] = "47 years"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    7061
# 70 years    5927
# 47 years    2696
# 74 years    2543
# 77 years    1681
# Name: count, dtype: int64

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown        752544
# 69-80 years     30243
# 75 years        21692
# 65 years        20092
# 87 years        19024
# 62 years        15728
# 59 years        14036
# 67 years        13022
# 82 years        13016
# 64 years        11159
# 76 years         9418
# 78 years         8312
# 66 years         7814
# 52-83 years      7085
# 69 years         6894
# 70 years         5927
# 71 years         4241
# 80 years         4195
# 58 years         3910
# 81 years         3873
# 56 years         3847
# 74 years         3842
# 46 years         3713
# 63 years         3063
# 54 years         2891
# 47 years         2696
# 83 years         2614
# 89 years         2586
# 79 years         1964
# 57-62 years      1934
# 77 years         1681
# 61 years         1191
# Name: count, dtype: int64

# %%
# adata_final_umap.write_h5ad("../9_annotate_level3/0514_rename_level3/output_allhuman/work_0514/scPoli_concat_level3_marker_all_metadata.h5ad")

# %% [markdown]
# #### intervention

# %%
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].astype(str)
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].replace('nan', float('nan'))
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].fillna('Unknown')

# %%
####GSE224587
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_final_umap.obs.loc[mask, "intervention"] = "Environment(cigarette smoke)+Hypercholesterolemia"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Environment(cigarette smoke)+Hypercholesterolemia    81796
# Name: count, dtype: int64

# %%
####GSE237230
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_1","GSE237230_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_3","GSE237230_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+Hyperlipidemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_5","GSE237230_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+Hyperlipidemia+Hyperuricemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_7","GSE237230_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hyperlipidemia+Familiarity for AAA"
mask = adata_final_umap.obs["dataset"] == "GSE237230"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Ex-smoker+Hypertension+Hyperlipidemia+Hyperuricemia    1652
# Ex-smoker+Hypertension+CHD                             1299
# Ex-smoker+Hyperlipidemia+Familiarity for AAA            825
# Ex-smoker+Hypertension+Hyperlipidemia                   443
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1","GSE166676_2","GSE166676_3","GSE166676_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker(50%)+Hypertension(50%)+Hyperlipidemia(50%)+COPD(25%)"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5","GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker(or ex)+Hypertension+Hyperlipidemia"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Smoker(50%)+Hypertension(50%)+Hyperlipidemia(50%)+COPD(25%)    7085
# Smoker(or ex)+Hypertension+Hyperlipidemia                      1934
# Name: count, dtype: int64

# %%
####GSE155468
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "None"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Diabetes mellitus"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Chronic obstructive pulmonary disease+Bicuspid aortic valve"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes mellitus+Hypertension+Aortic valve regurgitation+Bicuspid aortic valve"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes mellitus+Hypertension+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Chronic obstructive pulmonary disease+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_9"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_10"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_11"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Aortic valve regurgitation"
mask = adata_final_umap.obs["dataset"] == "GSE155468"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Hypertension                                                                       14326
# Hypertension+Aortic valve regurgitation                                             6411
# Diabetes mellitus+Hypertension+Aortic valve regurgitation                           6348
# Hypertension+Chronic obstructive pulmonary disease+Aortic valve regurgitation       4791
# Hypertension+Chronic obstructive pulmonary disease+Bicuspid aortic valve            4227
# Hypertension+Diabetes mellitus                                                      3906
# Diabetes mellitus+Hypertension+Aortic valve regurgitation+Bicuspid aortic valve     3616
# None                                                                                3063
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker+Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_3", "GSE159677_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified           19024
# Smoker+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified                  13229
# Smoker+Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified    13016
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD+Diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe(plaque severity)+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe(plaque severity)+CHD               7061
# Moderate(plaque severity)+CHD+Diabetes    5927
# Moderate(plaque severity)+CHD             4377
# Moderate(plaque severity)                 2543
# Name: count, dtype: int64

# %%
####GSE234077
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ischemic foot ulcer"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_9"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_10"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ischemic rest pain"
mask = adata_final_umap.obs["dataset"] == "GSE234077"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe carotid stenosis without stroke    25763
# Claudication                              23710
# Ischemic foot ulcer                        6826
# Ischemic rest pain                         4885
# Name: count, dtype: int64

# %%
####GSE131778
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Non-smoke+Impaired fasting glucose+ type 2 diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Non-smoke+Impaired fasting glucose+ type 3 diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Interstitial lung diseas"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Interstitial lung diseas"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Familial hypercholesterolemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Familial hypercholesterolemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Dextrocardia and transposition of the great arteries"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Dextrocardia and transposition of the great arteries"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe carotid stenosis without stroke    25763
# Claudication                              23710
# Ischemic foot ulcer                        6826
# Ischemic rest pain                         4885
# Name: count, dtype: int64

# %% [markdown]
# #### Plaque Type of measure

# %%
adata_final_umap.obs["Plaque_type"] = "Unknown"

# %%
datasets_to_change = [
    '1_JD',
    '2_ZDZJ',
    'AAA-MAX',
    'AAA-P',
    'AAA-PRO',
    'AIOD-3LIB',
    'AS-FA',
    'CFA-BWD',
    'CFA-PLA',
    'IAISR',
    'ISR-7-1',
    'POP-ISR-A',
    'POP-ISR2-B',
    'TAA-B1-5-3LIB',
    'TAA-A1-5-3LIB',
    'TAD1-Z3-3LIB',
    'TAD2-Z1-3LIB'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "Plaque_type"] = "Unstable"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["Plaque_type"].value_counts()
# Out:
# Plaque_type
# Unstable    152880
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AS-POP',
    'CBT',
    'IA-1-3LIB',
    'ISR-7-2',
    'ISR-8',
    'ISR-9',
    'SFA-8'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "Plaque_type"] = "Stable"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["Plaque_type"].value_counts()
# Out:
# Plaque_type
# Stable    60757
# Name: count, dtype: int64

# %% [markdown]
# #### gender

# %%
adata_final_umap.obs['gender'].value_counts()
# Out:
# gender
# Unknown     295509
# Male        212204
# Female       76499
# Mix(1:1)      8446
# Name: count, dtype: int64

# %%
adata_final_umap.obs['gender'] = adata_final_umap.obs['gender'].astype(str)
adata_final_umap.obs['gender'] = adata_final_umap.obs['gender'].replace('nan', float('nan'))
adata_final_umap.obs['gender'] = adata_final_umap.obs['gender'].fillna('Unknown')

# %%
adata_final_umap.obs['gender'].value_counts()
# Out:
# gender
# Unknown     707098
# Male        212204
# Female       76499
# Mix(1:1)      8446
# Name: count, dtype: int64

# %%
datasets_to_change = [
    '2_ZDZJ',
    'AAA-MAX',
    'AAA-P',
    'AAA-PRO',
    'IA-1-3LIB',
    'CBT',
    'CFA-BWD',
    'CFA-PLA',
    'AS-CFA',
    'AS-FA',
    'AS-POP',
    'SFA-8',
    'IAISR',
    'ISR-7-1',
    'ISR-7-2',
    'ISR-8',
    'ISR-9',
    'POP-ISR-A',
    'POP-ISR2-B',
    'TAA-B1-5-3LIB',
    'TAA-A1-5-3LIB',
    'TAD1-Z3-3LIB',
    'TAD2-Z1-3LIB'
]
mask = adata_final_umap.obs["dataset"].isin(datasets_to_change)
adata_final_umap.obs.loc[mask, "gender"] = "Male"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs["gender"].value_counts()
# Out:
# gender
# Male    194364
# Name: count, dtype: int64

# %%
adata_final_umap.obs['gender'].value_counts()
# Out:
# gender
# Unknown     512734
# Male        406568
# Female       76499
# Mix(1:1)      8446
# Name: count, dtype: int64

# %% [markdown]
# #### age of measure

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown        752544
# 69-80 years     30243
# 75 years        21692
# 65 years        20092
# 87 years        19024
# 62 years        15728
# 59 years        14036
# 67 years        13022
# 82 years        13016
# 64 years        11159
# 76 years         9418
# 78 years         8312
# 66 years         7814
# 52-83 years      7085
# 69 years         6894
# 70 years         5927
# 71 years         4241
# 80 years         4195
# 58 years         3910
# 81 years         3873
# 56 years         3847
# 74 years         3842
# 46 years         3713
# 63 years         3063
# 54 years         2891
# 47 years         2696
# 83 years         2614
# 89 years         2586
# 79 years         1964
# 57-62 years      1934
# 77 years         1681
# 61 years         1191
# Name: count, dtype: int64

# %%
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].astype(str)
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].replace('nan', float('nan'))
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].fillna('Unknown')

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown        752544
# 69-80 years     30243
# 75 years        21692
# 65 years        20092
# 87 years        19024
# 62 years        15728
# 59 years        14036
# 67 years        13022
# 82 years        13016
# 64 years        11159
# 76 years         9418
# 78 years         8312
# 66 years         7814
# 52-83 years      7085
# 69 years         6894
# 70 years         5927
# 71 years         4241
# 80 years         4195
# 58 years         3910
# 81 years         3873
# 56 years         3847
# 74 years         3842
# 46 years         3713
# 63 years         3063
# 54 years         2891
# 47 years         2696
# 83 years         2614
# 89 years         2586
# 79 years         1964
# 57-62 years      1934
# 77 years         1681
# 61 years         1191
# Name: count, dtype: int64

# %%
####2_ZDZJ
mask = adata_final_umap.obs["dataset"] == "2_ZDZJ"
adata_final_umap.obs.loc[mask, "age"] = "70 years"
mask = adata_final_umap.obs["dataset"] == "2_ZDZJ"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 70 years    15279
# Name: count, dtype: int64

# %%
####AAA-MAX
mask = adata_final_umap.obs["dataset"] == "AAA-MAX"
adata_final_umap.obs.loc[mask, "age"] = "65 years"
mask = adata_final_umap.obs["dataset"] == "AAA-MAX"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 65 years    7043
# Name: count, dtype: int64

# %%
####AAA-P
mask = adata_final_umap.obs["dataset"] == "AAA-P"
adata_final_umap.obs.loc[mask, "age"] = "58 years"
mask = adata_final_umap.obs["dataset"] == "AAA-P"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 58 years    8894
# Name: count, dtype: int64

# %%
####AAA-PRO
mask = adata_final_umap.obs["dataset"] == "AAA-PRO"
adata_final_umap.obs.loc[mask, "age"] = "60 years"
mask = adata_final_umap.obs["dataset"] == "AAA-PRO"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 60 years    9192
# Name: count, dtype: int64

# %%
####AIOD-3LIB
mask = adata_final_umap.obs["dataset"] == "AIOD-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "55 years"
mask = adata_final_umap.obs["dataset"] == "AIOD-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 55 years    12668
# Name: count, dtype: int64

# %%
####IA-1-3LIB
mask = adata_final_umap.obs["dataset"] == "IA-1-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "61 years"
mask = adata_final_umap.obs["dataset"] == "IA-1-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 61 years    10331
# Name: count, dtype: int64

# %%
####CBT
mask = adata_final_umap.obs["dataset"] == "CBT"
adata_final_umap.obs.loc[mask, "age"] = "59 years"
mask = adata_final_umap.obs["dataset"] == "CBT"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    8266
# Name: count, dtype: int64

# %%
####CFA-BWD
mask = adata_final_umap.obs["dataset"] == "CFA-BWD"
adata_final_umap.obs.loc[mask, "age"] = "55 years"
mask = adata_final_umap.obs["dataset"] == "CFA-BWD"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 55 years    7359
# Name: count, dtype: int64

# %%
####CFA-PLA
mask = adata_final_umap.obs["dataset"] == "CFA-PLA"
adata_final_umap.obs.loc[mask, "age"] = "53 years"
mask = adata_final_umap.obs["dataset"] == "CFA-PLA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 53 years    7697
# Name: count, dtype: int64

# %%
####AS-CFA
mask = adata_final_umap.obs["dataset"] == "AS-CFA"
adata_final_umap.obs.loc[mask, "age"] = "73 years"
mask = adata_final_umap.obs["dataset"] == "AS-CFA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 73 years    8539
# Name: count, dtype: int64

# %%
####AS-FA
mask = adata_final_umap.obs["dataset"] == "AS-FA"
adata_final_umap.obs.loc[mask, "age"] = "60 years"
mask = adata_final_umap.obs["dataset"] == "AS-FA"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 60 years    12682
# Name: count, dtype: int64

# %%
####AS-POP
mask = adata_final_umap.obs["dataset"] == "AS-POP"
adata_final_umap.obs.loc[mask, "age"] = "65 years"
mask = adata_final_umap.obs["dataset"] == "AS-POP"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 65 years    7232
# Name: count, dtype: int64

# %%
####SFA-8
mask = adata_final_umap.obs["dataset"] == "SFA-8"
adata_final_umap.obs.loc[mask, "age"] = "48 years"
mask = adata_final_umap.obs["dataset"] == "SFA-8"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 48 years    7711
# Name: count, dtype: int64

# %%
# ####IAISR
# mask = adata_final.obs["dataset"] == "IAISR"
# adata_final.obs.loc[mask, "age"] = "48 years"
# mask = adata_final.obs["dataset"] == "IAISR"
# adata_disease = adata_final[mask, :].copy()
# adata_disease.obs['age'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
####ISR-7-1
mask = adata_final_umap.obs["dataset"] == "ISR-7-1"
adata_final_umap.obs.loc[mask, "age"] = "57 years"
mask = adata_final_umap.obs["dataset"] == "ISR-7-1"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 57 years    9610
# Name: count, dtype: int64

# %%
####ISR-7-2
mask = adata_final_umap.obs["dataset"] == "ISR-7-2"
adata_final_umap.obs.loc[mask, "age"] = "69 years"
mask = adata_final_umap.obs["dataset"] == "ISR-7-2"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 69 years    9153
# Name: count, dtype: int64

# %%
####ISR-8
mask = adata_final_umap.obs["dataset"] == "ISR-8"
adata_final_umap.obs.loc[mask, "age"] = "68 years"
mask = adata_final_umap.obs["dataset"] == "ISR-8"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 68 years    4655
# Name: count, dtype: int64

# %%
####ISR-9
mask = adata_final_umap.obs["dataset"] == "ISR-9"
adata_final_umap.obs.loc[mask, "age"] = "71 years"
mask = adata_final_umap.obs["dataset"] == "ISR-9"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 71 years    13409
# Name: count, dtype: int64

# %%
####POP-ISR-A
mask = adata_final_umap.obs["dataset"] == "POP-ISR-A"
adata_final_umap.obs.loc[mask, "age"] = "61 years"
mask = adata_final_umap.obs["dataset"] == "POP-ISR-A"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 61 years    10742
# Name: count, dtype: int64

# %%
####POP-ISR2-B
mask = adata_final_umap.obs["dataset"] == "POP-ISR2-B"
adata_final_umap.obs.loc[mask, "age"] = "59 years"
mask = adata_final_umap.obs["dataset"] == "POP-ISR2-B"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    10916
# Name: count, dtype: int64

# %%
####TAA-A1-5-3LIB
mask = adata_final_umap.obs["dataset"] == "TAA-A1-5-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "73 years"
mask = adata_final_umap.obs["dataset"] == "TAA-A1-5-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 73 years    11507
# Name: count, dtype: int64

# %%
####TAA-B1-5-3LIB
mask = adata_final_umap.obs["dataset"] == "TAA-B1-5-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "68 years"
mask = adata_final_umap.obs["dataset"] == "TAA-B1-5-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 68 years    4415
# Name: count, dtype: int64

# %%
####TAD1-Z3-3LIB
mask = adata_final_umap.obs["dataset"] == "TAD1-Z3-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "63 years"
mask = adata_final_umap.obs["dataset"] == "TAD1-Z3-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 63 years    8193
# Name: count, dtype: int64

# %%
####TAD2-Z1-3LIB
mask = adata_final_umap.obs["dataset"] == "TAD2-Z1-3LIB"
adata_final_umap.obs.loc[mask, "age"] = "70 years"
mask = adata_final_umap.obs["dataset"] == "TAD2-Z1-3LIB"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 70 years    1532
# Name: count, dtype: int64

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown        552878
# 65 years        34367
# 59 years        33218
# 69-80 years     30243
# 70 years        22738
# 61 years        22264
# 60 years        21874
# 75 years        21692
# 73 years        20046
# 87 years        19024
# 71 years        17650
# 69 years        16047
# 62 years        15728
# 67 years        13022
# 82 years        13016
# 58 years        12804
# 55 years        12668
# 63 years        11256
# 64 years        11159
# 57 years         9610
# 76 years         9418
# 68 years         9070
# 78 years         8312
# 66 years         7814
# 48 years         7711
# 53 years         7697
# 52-83 years      7085
# 80 years         4195
# 81 years         3873
# 56 years         3847
# 74 years         3842
# 46 years         3713
# 54 years         2891
# 47 years         2696
# 83 years         2614
# 89 years         2586
# 79 years         1964
# 57-62 years      1934
# 77 years         1681
# Name: count, dtype: int64

# %%
adata_final_umap.write_h5ad("../9_annotate_level3/0521_no_Basophil/output_allhuman/scPoli_concat_level3_marker_all_metadata.h5ad")

# %%
adata_final_umap.obs["sample"].nunique()
# Out:
# 193

# %%
adata_final_umap
# Out:
# AnnData object with n_obs × n_vars = 1004247 × 28868
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'atlas_key', 'species', 'barcode_for_match', 'match_id', 'leiden', 'cell_type_pred', 'cell_type_uncert', 'query', 'cell_type_pred_ref', 'cell_type_level1_human', 'cell_type_level1_corrected', 'cell_type_level2', 'cell_type_level3', 'Plaque_type'
#     var: 'original_gene_names', 'ensembl_id'
#     uns: 'neighbors', 'umap'
#     obsm: 'X_scPoli', 'X_umap'
#     layers: 'counts', 'raw_decontXcounts', 'rounded_corrected_counts', 'uncorrected_counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # end
