# %%
import scanpy as sc

# %%
###rename--还没写进去umap
adata_final_umap = sc.read_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human.h5ad")
adata_final_umap
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 1032623 × 28870
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'cell_type_level2', 'cell_type_level3'
#     var: 'original_gene_names', 'ensembl_id'
#     layers: 'raw_decontXcounts', 'rounded_corrected_counts', 'uncorrected_counts'

# %%
adata_final_umap.obs['tissue'].value_counts()
# Out:
# tissue
# Aorta              245083
# Carotid Artery     218086
# Coronary artery     59799
# Coronary Artery     43497
# Femoral Artery      35643
# Name: count, dtype: int64

# %%
adata_final_umap.obs['symptoms'].value_counts()
# Out:
# symptoms
# not stated         430515
# Atherosclerosis    297226
# AAA                108505
# Healthy            102595
# ATAA                38669
# AD                  33066
# MF                  16147
# TAA                  5900
# Name: count, dtype: int64

# %% [markdown]
# #### tissue

# %%
##改组织部位
####GSE226492
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].astype(str)
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_1", "GSE226492_2", "GSE226492_3"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_4", "GSE226492_5", "GSE226492_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE226492_7", "GSE226492_8", "GSE226492_9","GSE226492_10"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE226492"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Aorta              49213
# Ascending Aorta    31973
# Abdominal Aorta    12872
# Name: count, dtype: int64

# %%
####GSE224587
sample_mask = adata_final_umap.obs["sample"].isin(["GSE224587_1", "GSE224587_2", "GSE224587_3", "GSE224587_4", "GSE224587_5", "GSE224587_6", "GSE224587_7", "GSE224587_8"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    81977
# Name: count, dtype: int64

# %%
####GSE237230
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_1", "GSE237230_2", "GSE237230_3", "GSE237230_4", "GSE237230_5", "GSE237230_6", "GSE237230_7", "GSE237230_8"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE237230"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    4367
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1", "GSE166676_2", "GSE166676_3", "GSE166676_4", "GSE166676_5", "GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Abdominal Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Abdominal Aorta    11943
# Name: count, dtype: int64

# %%
####GSE143921
sample_mask = adata_final_umap.obs["sample"].isin(["GSE143921_1", "GSE143921_2", "GSE143921_3", "GSE143921_4", "GSE143921_5", "GSE143921_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE143921"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Ascending Aorta    5900
# Name: count, dtype: int64

# %%
####GSE155468
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_1", "GSE155468_2", "GSE155468_3", "GSE155468_4", "GSE155468_5", "GSE155468_6",
                                                   "GSE155468_7", "GSE155468_8", "GSE155468_9", "GSE155468_10", "GSE155468_11"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Ascending Aorta"
mask = adata_final_umap.obs["dataset"] == "GSE155468"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Ascending Aorta    46838
# Name: count, dtype: int64

# %%
####GSE155512
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155512_1", "GSE155512_2", "GSE155512_3"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE155512"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    8855
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2", "GSE159677_3", "GSE159677_4", "GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    45494
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1", "GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3", "GSE179159_4", "GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    15830
# Carotid Artery      4271
# Name: count, dtype: int64

# %%
####GSE210152
sample_mask = adata_final_umap.obs["sample"].isin(["GSE210152_1", "GSE210152_2", "GSE210152_3", "GSE210152_4", "GSE210152_5", "GSE210152_6"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE210152"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    30362
# Name: count, dtype: int64

# %%
####GSE224273
sample_mask = adata_final_umap.obs["sample"].isin(["GSE224273_1", "GSE224273_2", "GSE224273_3", "GSE224273_4", "GSE224273_5", "GSE224273_6", "GSE224273_7"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE224273"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    9887
# Name: count, dtype: int64

# %%
####GSE247238
mask = adata_final_umap.obs["dataset"] == "GSE247238"
adata_final_umap.obs.loc[mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE247238"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    4732
# Name: count, dtype: int64

# %%
####GSE234077
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_2", "GSE234077_7", "GSE234077_9"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Carotid Artery"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_1", "GSE234077_3", "GSE234077_4", "GSE234077_5", "GSE234077_6", "GSE234077_8", "GSE234077_10"])
adata_final_umap.obs.loc[sample_mask, "tissue"] = "Femoral Artery"
mask = adata_final_umap.obs["dataset"] == "GSE234077"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Femoral Artery    35643
# Carotid Artery    26564
# Name: count, dtype: int64

# %%
####GSE253904
mask = adata_final_umap.obs["dataset"] == "GSE253904"
adata_final_umap.obs.loc[mask, "tissue"] = "Carotid Artery"
mask = adata_final_umap.obs["dataset"] == "GSE253904"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Carotid Artery    76421
# Name: count, dtype: int64

# %%
####GSE131778
mask = adata_final_umap.obs["dataset"] == "GSE131778"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE131778"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    11500
# Name: count, dtype: int64

# %%
####GSE184073
mask = adata_final_umap.obs["dataset"] == "GSE184073"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE184073"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    1688
# Name: count, dtype: int64

# %%
####GSE196943
mask = adata_final_umap.obs["dataset"] == "GSE196943"
adata_final_umap.obs.loc[mask, "tissue"] = "Coronary Artery"
mask = adata_final_umap.obs["dataset"] == "GSE196943"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['tissue'].value_counts()
# Out:
# tissue
# Coronary Artery    25979
# Name: count, dtype: int64

# %%
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].replace('nan', 'Unknown')
adata_final_umap.obs['tissue'] = adata_final_umap.obs['tissue'].replace('Coronary artery', 'Coronary Artery')
adata_final_umap.obs['tissue'].value_counts()
# Out:
# tissue
# Unknown            430515
# Carotid Artery     206586
# Coronary Artery    114796
# Abdominal Aorta    111159
# Ascending Aorta     84711
# Aorta               49213
# Femoral Artery      35643
# Name: count, dtype: int64

# %%
adata_final_umap.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### symptoms

# %%
####GSE224587
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_final_umap.obs.loc[mask, "symptoms"] = "Atherosclerosis"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# Atherosclerosis    81977
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5"])
adata_final_umap.obs.loc[sample_mask, "symptoms"] = "Healthy"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# AAA        7438
# Healthy    4505
# Name: count, dtype: int64

# %%
####GSE143921
sample_mask = adata_final_umap.obs["sample"].isin(["GSE143921_1", "GSE143921_2", "GSE143921_3"])
adata_final_umap.obs.loc[sample_mask, "symptoms"] = "Healthy"
mask = adata_final_umap.obs["dataset"] == "GSE143921"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['symptoms'].value_counts()
# Out:
# symptoms
# TAA        3254
# Healthy    2646
# Name: count, dtype: int64

# %% [markdown]
# #### age

# %%
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].astype(str)
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].replace('nan', float('nan'))
adata_final_umap.obs['age'] = adata_final_umap.obs['age'].fillna('Unknown')

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown                776742
# 69-80 years             30362
# 75 years                21764
# 65 years                20124
# 87 years                19036
# 62 years                15752
# 82 years                13206
# 67 years                13113
# 64 years                11200
# 76 years                 9437
# 67.2 years(average)      9289
# 77 years                 8850
# 78 years                 8400
# 66 years                 7839
# 59 years                 7045
# 69 years                 6929
# 70 years                 5935
# 80 years                 4205
# 71 years                 4201
# 81 years                 3989
# 58 years                 3905
# 74 years                 3903
# 56 years                 3900
# 46 years                 3754
# 63 years                 3070
# 54 years                 2890
# 47 years                 2759
# 59.8 years(average)      2654
# 83 years                 2614
# 89 years                 2590
# 79 years                 1974
# 61 years                 1192
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1", "GSE166676_2", "GSE166676_3", "GSE166676_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "52-83 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5", "GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "age"] = "57-62 years"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 52-83 years    7438
# 57-62 years    4505
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2"])
adata_final_umap.obs.loc[sample_mask, "age"] = "82 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_3", "GSE159677_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "87 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "age"] = "65 years"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 87 years    19036
# 65 years    13252
# 82 years    13206
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1"])
adata_final_umap.obs.loc[sample_mask, "age"] = "74 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "age"] = "77 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3"])
adata_final_umap.obs.loc[sample_mask, "age"] = "70 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_4"])
adata_final_umap.obs.loc[sample_mask, "age"] = "59 years"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "age"] = "47 years"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    7136
# 70 years    5935
# 47 years    2759
# 74 years    2557
# 77 years    1714
# Name: count, dtype: int64

# %%
adata_final_umap.obs['age'].value_counts()
# Out:
# age
# Unknown        776742
# 69-80 years     30362
# 75 years        21764
# 65 years        20124
# 87 years        19036
# 62 years        15752
# 59 years        14181
# 82 years        13206
# 67 years        13113
# 64 years        11200
# 76 years         9437
# 78 years         8400
# 66 years         7839
# 52-83 years      7438
# 69 years         6929
# 70 years         5935
# 57-62 years      4505
# 80 years         4205
# 71 years         4201
# 81 years         3989
# 58 years         3905
# 74 years         3903
# 56 years         3900
# 46 years         3754
# 63 years         3070
# 54 years         2890
# 47 years         2759
# 83 years         2614
# 89 years         2590
# 79 years         1974
# 77 years         1714
# 61 years         1192
# Name: count, dtype: int64

# %%
# adata_final_umap.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### intervention

# %%
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].astype(str)
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].replace('nan', float('nan'))
adata_final_umap.obs['intervention'] = adata_final_umap.obs['intervention'].fillna('Unknown')

# %%
####GSE224587
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_final_umap.obs.loc[mask, "intervention"] = "Environment(cigarette smoke)+Hypercholesterolemia"
mask = adata_final_umap.obs["dataset"] == "GSE224587"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Environment(cigarette smoke)+Hypercholesterolemia    81977
# Name: count, dtype: int64

# %%
####GSE237230
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_1","GSE237230_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_3","GSE237230_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+Hyperlipidemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_5","GSE237230_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hypertension+Hyperlipidemia+Hyperuricemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE237230_7","GSE237230_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ex-smoker+Hyperlipidemia+Familiarity for AAA"
mask = adata_final_umap.obs["dataset"] == "GSE237230"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Ex-smoker+Hypertension+Hyperlipidemia+Hyperuricemia    1694
# Ex-smoker+Hypertension+CHD                             1346
# Ex-smoker+Hyperlipidemia+Familiarity for AAA            866
# Ex-smoker+Hypertension+Hyperlipidemia                   461
# Name: count, dtype: int64

# %%
####GSE166676
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_1","GSE166676_2","GSE166676_3","GSE166676_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker(50%)+Hypertension(50%)+Hyperlipidemia(50%)+COPD(25%)"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE166676_5","GSE166676_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker(or ex)+Hypertension+Hyperlipidemia"
mask = adata_final_umap.obs["dataset"] == "GSE166676"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Smoker(50%)+Hypertension(50%)+Hyperlipidemia(50%)+COPD(25%)    7438
# Smoker(or ex)+Hypertension+Hyperlipidemia                      4505
# Name: count, dtype: int64

# %%
####GSE155468
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "None"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Diabetes mellitus"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Chronic obstructive pulmonary disease+Bicuspid aortic valve"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes mellitus+Hypertension+Aortic valve regurgitation+Bicuspid aortic valve"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes mellitus+Hypertension+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Chronic obstructive pulmonary disease+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_9"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Aortic valve regurgitation"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_10"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE155468_11"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Aortic valve regurgitation"
mask = adata_final_umap.obs["dataset"] == "GSE155468"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Hypertension                                                                       14346
# Hypertension+Aortic valve regurgitation                                             6431
# Diabetes mellitus+Hypertension+Aortic valve regurgitation                           6347
# Hypertension+Chronic obstructive pulmonary disease+Aortic valve regurgitation       4800
# Hypertension+Chronic obstructive pulmonary disease+Bicuspid aortic valve            4318
# Hypertension+Diabetes mellitus                                                      3907
# Diabetes mellitus+Hypertension+Aortic valve regurgitation+Bicuspid aortic valve     3619
# None                                                                                3070
# Name: count, dtype: int64

# %%
####GSE159677
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_1", "GSE159677_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker+Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_3", "GSE159677_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE159677_5", "GSE159677_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Smoker+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified"
mask = adata_final_umap.obs["dataset"] == "GSE159677"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified           19036
# Smoker+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified                  13252
# Smoker+Diabetes(A1C)+Hypertension+Dyslipidemia+Statin(medicine)+Type VII Calcified    13206
# Name: count, dtype: int64

# %%
####GSE179159
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD+Diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe(plaque severity)+CHD"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE179159_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Moderate(plaque severity)+CHD"
mask = adata_final_umap.obs["dataset"] == "GSE179159"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe(plaque severity)+CHD               7136
# Moderate(plaque severity)+CHD+Diabetes    5935
# Moderate(plaque severity)+CHD             4473
# Moderate(plaque severity)                 2557
# Name: count, dtype: int64

# %%
####GSE234077
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ischemic foot ulcer"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Claudication"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_9"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Severe carotid stenosis without stroke"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE234077_10"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Ischemic rest pain"
mask = adata_final_umap.obs["dataset"] == "GSE234077"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe carotid stenosis without stroke    26564
# Claudication                              23907
# Ischemic foot ulcer                        6848
# Ischemic rest pain                         4888
# Name: count, dtype: int64

# %%
####GSE131778
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_1"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Non-smoke+Impaired fasting glucose+ type 2 diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_2"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Non-smoke+Impaired fasting glucose+ type 3 diabetes"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_3"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Interstitial lung diseas"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_4"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Interstitial lung diseas"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_5"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Familial hypercholesterolemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_6"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Hypertension+Familial hypercholesterolemia"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_7"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Dextrocardia and transposition of the great arteries"
sample_mask = adata_final_umap.obs["sample"].isin(["GSE131778_8"])
adata_final_umap.obs.loc[sample_mask, "intervention"] = "Dextrocardia and transposition of the great arteries"
adata_disease = adata_final_umap[mask, :].copy()
adata_disease.obs['intervention'].value_counts()
# Out:
# intervention
# Severe carotid stenosis without stroke    26564
# Claudication                              23907
# Ischemic foot ulcer                        6848
# Ischemic rest pain                         4888
# Name: count, dtype: int64

# %%
adata_final_umap.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# ### Measure data

# %% [markdown]
# #### Plaque Type

# %%
adata_final = sc.read_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")
adata_final
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 1032623 × 28870
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'cell_type_level2', 'cell_type_level3', 'Plaque_type'
#     var: 'original_gene_names', 'ensembl_id'
#     layers: 'raw_decontXcounts', 'rounded_corrected_counts', 'uncorrected_counts'

# %%
adata_final.obs["Plaque_type"] = "Unknown"

# %%
datasets_to_change = [
    '1_JD',
    '2_ZDZJ',
    'AAA-MAX',
    'AAA-P',
    'AAA-PRO',
    'AIOD-3LIB',
    'AS-FA',
    'CFA-BWD',
    'CFA-PLA',
    'IAISR',
    'ISR-7-1',
    'POP-ISR-A',
    'POP-ISR2-B',
    'TAA-B1-5-3LIB',
    'TAA-A1-5-3LIB',
    'TAD1-Z3-3LIB',
    'TAD2-Z1-3LIB'
]
mask = adata_final.obs["dataset"].isin(datasets_to_change)
adata_final.obs.loc[mask, "Plaque_type"] = "Unstable"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["Plaque_type"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Plaque_type
# Unstable    171841
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AS-POP',
    'CBT',
    'IA-1-3LIB',
    'ISR-7-2',
    'ISR-8',
    'ISR-9',
    'SFA-8'
]
mask = adata_final.obs["dataset"].isin(datasets_to_change)
adata_final.obs.loc[mask, "Plaque_type"] = "Stable"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["Plaque_type"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Plaque_type
# Stable    60506
# Name: count, dtype: int64

# %%
adata_final.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### gender

# %%
adata_final.obs['gender'].value_counts()
# Out:
# gender
# Unknown     300077
# Male        216082
# Female       76660
# Mix(1:1)      9289
# Name: count, dtype: int64

# %%
adata_final.obs['gender'] = adata_final.obs['gender'].astype(str)
adata_final.obs['gender'] = adata_final.obs['gender'].replace('nan', float('nan'))
adata_final.obs['gender'] = adata_final.obs['gender'].fillna('Unknown')

# %%
adata_final.obs['gender'].value_counts()
# Out:
# gender
# Unknown     730592
# Male        216082
# Female       76660
# Mix(1:1)      9289
# Name: count, dtype: int64

# %%
datasets_to_change = [
    '2_ZDZJ',
    'AAA-MAX',
    'AAA-P',
    'AAA-PRO',
    'IA-1-3LIB',
    'CBT',
    'CFA-BWD',
    'CFA-PLA',
    'AS-CFA',
    'AS-FA',
    'AS-POP',
    'SFA-8',
    'IAISR',
    'ISR-7-1',
    'ISR-7-2',
    'ISR-8',
    'ISR-9',
    'POP-ISR-A',
    'POP-ISR2-B',
    'TAA-B1-5-3LIB',
    'TAA-A1-5-3LIB',
    'TAD1-Z3-3LIB',
    'TAD2-Z1-3LIB'
]
mask = adata_final.obs["dataset"].isin(datasets_to_change)
adata_final.obs.loc[mask, "gender"] = "Male"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["gender"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# gender
# Male    213079
# Name: count, dtype: int64

# %%
adata_final.obs['gender'].value_counts()
# Out:
# gender
# Unknown     517513
# Male        429161
# Female       76660
# Mix(1:1)      9289
# Name: count, dtype: int64

# %%
# adata_final.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### age

# %%
adata_final.obs['age'].value_counts()
# Out:
# age
# Unknown        776742
# 69-80 years     30362
# 75 years        21764
# 65 years        20124
# 87 years        19036
# 62 years        15752
# 59 years        14181
# 82 years        13206
# 67 years        13113
# 64 years        11200
# 76 years         9437
# 78 years         8400
# 66 years         7839
# 52-83 years      7438
# 69 years         6929
# 70 years         5935
# 57-62 years      4505
# 80 years         4205
# 71 years         4201
# 81 years         3989
# 58 years         3905
# 74 years         3903
# 56 years         3900
# 46 years         3754
# 63 years         3070
# 54 years         2890
# 47 years         2759
# 83 years         2614
# 89 years         2590
# 79 years         1974
# 77 years         1714
# 61 years         1192
# Name: count, dtype: int64

# %%
adata_final.obs['age'] = adata_final.obs['age'].astype(str)
adata_final.obs['age'] = adata_final.obs['age'].replace('nan', float('nan'))
adata_final.obs['age'] = adata_final.obs['age'].fillna('Unknown')

# %%
adata_final.obs['age'].value_counts()
# Out:
# age
# Unknown        776742
# 69-80 years     30362
# 75 years        21764
# 65 years        20124
# 87 years        19036
# 62 years        15752
# 59 years        14181
# 82 years        13206
# 67 years        13113
# 64 years        11200
# 76 years         9437
# 78 years         8400
# 66 years         7839
# 52-83 years      7438
# 69 years         6929
# 70 years         5935
# 57-62 years      4505
# 80 years         4205
# 71 years         4201
# 81 years         3989
# 58 years         3905
# 74 years         3903
# 56 years         3900
# 46 years         3754
# 63 years         3070
# 54 years         2890
# 47 years         2759
# 83 years         2614
# 89 years         2590
# 79 years         1974
# 77 years         1714
# 61 years         1192
# Name: count, dtype: int64

# %%
####2_ZDZJ
mask = adata_final.obs["dataset"] == "2_ZDZJ"
adata_final.obs.loc[mask, "age"] = "70 years"
mask = adata_final.obs["dataset"] == "2_ZDZJ"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 70 years    15183
# Name: count, dtype: int64

# %%
####AAA-MAX
mask = adata_final.obs["dataset"] == "AAA-MAX"
adata_final.obs.loc[mask, "age"] = "65 years"
mask = adata_final.obs["dataset"] == "AAA-MAX"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 65 years    7038
# Name: count, dtype: int64

# %%
####AAA-P
mask = adata_final.obs["dataset"] == "AAA-P"
adata_final.obs.loc[mask, "age"] = "58 years"
mask = adata_final.obs["dataset"] == "AAA-P"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 58 years    8887
# Name: count, dtype: int64

# %%
####AAA-PRO
mask = adata_final.obs["dataset"] == "AAA-PRO"
adata_final.obs.loc[mask, "age"] = "60 years"
mask = adata_final.obs["dataset"] == "AAA-PRO"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 60 years    9186
# Name: count, dtype: int64

# %%
####AIOD-3LIB
mask = adata_final.obs["dataset"] == "AIOD-3LIB"
adata_final.obs.loc[mask, "age"] = "55 years"
mask = adata_final.obs["dataset"] == "AIOD-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 55 years    12664
# Name: count, dtype: int64

# %%
####IA-1-3LIB
mask = adata_final.obs["dataset"] == "IA-1-3LIB"
adata_final.obs.loc[mask, "age"] = "61 years"
mask = adata_final.obs["dataset"] == "IA-1-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 61 years    10280
# Name: count, dtype: int64

# %%
####CBT
mask = adata_final.obs["dataset"] == "CBT"
adata_final.obs.loc[mask, "age"] = "59 years"
mask = adata_final.obs["dataset"] == "CBT"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    8366
# Name: count, dtype: int64

# %%
####CFA-BWD
mask = adata_final.obs["dataset"] == "CFA-BWD"
adata_final.obs.loc[mask, "age"] = "55 years"
mask = adata_final.obs["dataset"] == "CFA-BWD"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 55 years    7378
# Name: count, dtype: int64

# %%
####CFA-PLA
mask = adata_final.obs["dataset"] == "CFA-PLA"
adata_final.obs.loc[mask, "age"] = "53 years"
mask = adata_final.obs["dataset"] == "CFA-PLA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 53 years    7720
# Name: count, dtype: int64

# %%
####AS-CFA
mask = adata_final.obs["dataset"] == "AS-CFA"
adata_final.obs.loc[mask, "age"] = "73 years"
mask = adata_final.obs["dataset"] == "AS-CFA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 73 years    8532
# Name: count, dtype: int64

# %%
####AS-FA
mask = adata_final.obs["dataset"] == "AS-FA"
adata_final.obs.loc[mask, "age"] = "60 years"
mask = adata_final.obs["dataset"] == "AS-FA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 60 years    12678
# Name: count, dtype: int64

# %%
####AS-POP
mask = adata_final.obs["dataset"] == "AS-POP"
adata_final.obs.loc[mask, "age"] = "65 years"
mask = adata_final.obs["dataset"] == "AS-POP"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 65 years    7225
# Name: count, dtype: int64

# %%
####SFA-8
mask = adata_final.obs["dataset"] == "SFA-8"
adata_final.obs.loc[mask, "age"] = "48 years"
mask = adata_final.obs["dataset"] == "SFA-8"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 48 years    7716
# Name: count, dtype: int64

# %%
####IAISR
mask = adata_final.obs["dataset"] == "IAISR"
adata_final.obs.loc[mask, "age"] = "48 years"
mask = adata_final.obs["dataset"] == "IAISR"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 48 years    19055
# Name: count, dtype: int64

# %%
####ISR-7-1
mask = adata_final.obs["dataset"] == "ISR-7-1"
adata_final.obs.loc[mask, "age"] = "57 years"
mask = adata_final.obs["dataset"] == "ISR-7-1"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 57 years    9607
# Name: count, dtype: int64

# %%
####ISR-7-2
mask = adata_final.obs["dataset"] == "ISR-7-2"
adata_final.obs.loc[mask, "age"] = "69 years"
mask = adata_final.obs["dataset"] == "ISR-7-2"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 69 years    9176
# Name: count, dtype: int64

# %%
####ISR-8
mask = adata_final.obs["dataset"] == "ISR-8"
adata_final.obs.loc[mask, "age"] = "68 years"
mask = adata_final.obs["dataset"] == "ISR-8"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 68 years    4653
# Name: count, dtype: int64

# %%
####ISR-9
mask = adata_final.obs["dataset"] == "ISR-9"
adata_final.obs.loc[mask, "age"] = "71 years"
mask = adata_final.obs["dataset"] == "ISR-9"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 71 years    13090
# Name: count, dtype: int64

# %%
####POP-ISR-A
mask = adata_final.obs["dataset"] == "POP-ISR-A"
adata_final.obs.loc[mask, "age"] = "61 years"
mask = adata_final.obs["dataset"] == "POP-ISR-A"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 61 years    10684
# Name: count, dtype: int64

# %%
####POP-ISR2-B
mask = adata_final.obs["dataset"] == "POP-ISR2-B"
adata_final.obs.loc[mask, "age"] = "59 years"
mask = adata_final.obs["dataset"] == "POP-ISR2-B"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 59 years    10914
# Name: count, dtype: int64

# %%
####TAA-A1-5-3LIB
mask = adata_final.obs["dataset"] == "TAA-A1-5-3LIB"
adata_final.obs.loc[mask, "age"] = "73 years"
mask = adata_final.obs["dataset"] == "TAA-A1-5-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 73 years    11575
# Name: count, dtype: int64

# %%
####TAA-B1-5-3LIB
mask = adata_final.obs["dataset"] == "TAA-B1-5-3LIB"
adata_final.obs.loc[mask, "age"] = "68 years"
mask = adata_final.obs["dataset"] == "TAA-B1-5-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 68 years    4416
# Name: count, dtype: int64

# %%
####TAD1-Z3-3LIB
mask = adata_final.obs["dataset"] == "TAD1-Z3-3LIB"
adata_final.obs.loc[mask, "age"] = "63 years"
mask = adata_final.obs["dataset"] == "TAD1-Z3-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 63 years    8188
# Name: count, dtype: int64

# %%
####TAD2-Z1-3LIB
mask = adata_final.obs["dataset"] == "TAD2-Z1-3LIB"
adata_final.obs.loc[mask, "age"] = "70 years"
mask = adata_final.obs["dataset"] == "TAD2-Z1-3LIB"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs['age'].value_counts()
# Out:
# age
# 70 years    1532
# Name: count, dtype: int64

# %%
adata_final.obs['age'].value_counts()
# Out:
# age
# Unknown        550999
# 65 years        34387
# 59 years        33461
# 69-80 years     30362
# 48 years        26771
# 70 years        22650
# 61 years        22156
# 60 years        21864
# 75 years        21764
# 73 years        20107
# 55 years        20042
# 87 years        19036
# 71 years        17291
# 69 years        16105
# 62 years        15752
# 82 years        13206
# 67 years        13113
# 58 years        12792
# 63 years        11258
# 64 years        11200
# 57 years         9607
# 76 years         9437
# 68 years         9069
# 78 years         8400
# 66 years         7839
# 53 years         7720
# 52-83 years      7438
# 57-62 years      4505
# 80 years         4205
# 81 years         3989
# 74 years         3903
# 56 years         3900
# 46 years         3754
# 54 years         2890
# 47 years         2759
# 83 years         2614
# 89 years         2590
# 79 years         1974
# 77 years         1714
# Name: count, dtype: int64

# %%
# adata_final.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### symptoms

# %%
adata_final.obs['symptoms'] = adata_final.obs['symptoms'].astype(str)

# %%
datasets_to_change = [
    '1_JD',
    '2_ZDZJ',
    'AAA',
    'AAA_1_3LIB',
    'AAA_2_3LIB',
    'AAA_3_3LIB',
    'AAA_4_3LIB',
    'AAA_8',
    'AAA_9',
    'AAA_D',
    'AAA_MAX',
    'AAA_P',
    'AAA_PRO',
    'RRAA'
]
mask = adata_final.obs["dataset"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "AAA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# symptoms
# AAA    53315
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'AIOD_3LIB',
    'IA_1_3LIB'
]
mask = adata_final.obs["sample"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "IAA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# symptoms
# IAA    22944
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'CBT'
]
mask = adata_final.obs["sample"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "CBT"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# symptoms
# CBT    8366
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'CFA_BWD',
    'CFA_PLA',
    'AS_CFA',
    'AS_FA',
    'AS_POP',
    'MXT_matrix',
    'SFA_8'
]
mask = adata_final.obs["sample"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "Atherosclerosis"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# symptoms
# Atherosclerosis    51249
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'IAISR',
    'ISR_7_1',
    'ISR_7_2',
    'ISR_8',
    'ISR_9',
    'LCH_matrix',
    'LHJ20230414_matrix',
    'LW_matrix',
    'POP_ISR_A',
    'POP_ISR2_B',
    'S221031_matrix',
    'ZNB_matrix'
]
mask = adata_final.obs["sample"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "Atherosclerosis,ISR"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# symptoms
# Atherosclerosis,ISR    96864
# Name: count, dtype: int64

# %%
datasets_to_change = [
    'TAA_A1_3_3LIB',
    'TAA_A1_5_3LIB',
    'TAA_B1_5_3LIB',
    'TAA_Z1',
    'TAA_Z3',
    'TAD_AD1_2_3LIB',
    'TAD1_Z3_3LIB',
    'TAD2_Z1_3LIB',
    'TAD2_Z2_3LIB',
    'TAD2_Z3_3LIB'
]
mask = adata_final.obs["sample"].isin(datasets_to_change)
adata_final.obs.loc[mask, "symptoms"] = "TAA"
adata_disease = adata_final[mask, :].copy()
adata_disease.obs["symptoms"].value_counts()
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# symptoms
# TAA    80639
# Name: count, dtype: int64

# %%
adata_final.write_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")

# %% [markdown]
# #### tissue

# %% [markdown]
# ### data statistics

# %%
adata_final = sc.read_h5ad("../9_annotate_level3/output_260420/Big-atlas-getlevel3-human-matedata.h5ad")
adata_final
# Out:
# /home/lixiangyu/anaconda3/envs/zr_r420/lib/python3.9/site-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 1032623 × 28870
#     obs: 'sample', 'dataset', 'symptoms', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.cxds_score', 'decontX_contamination', 'decontX_clusters', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'n_counts', 'size_factors', 'cell_type_level1', 'scDblFinder.sample', 'gender', 'age', 'intervention', 'tissue', 'cell_type_level2', 'cell_type_level3', 'Plaque_type'
#     var: 'original_gene_names', 'ensembl_id'
#     layers: 'raw_decontXcounts', 'rounded_corrected_counts', 'uncorrected_counts'
